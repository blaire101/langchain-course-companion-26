# %% [markdown]
# # 1. Models, Prompts and Structured Output
# Original practice notebook aligned to the public course topic.

# %%
from typing import Literal
from pydantic import BaseModel, Field
from langchain.chat_models import init_chat_model
from dotenv import load_dotenv
load_dotenv()

# %%
class SupportTicket(BaseModel):
    category: Literal['billing', 'technical', 'product', 'other']
    priority: Literal['low', 'medium', 'high']
    summary: str = Field(description='One sentence summary')

# %%
model = init_chat_model('openai:gpt-4.1-mini', temperature=0)
structured_model = model.with_structured_output(SupportTicket)

# %%
ticket = 'Our production API is down and all users are affected.'
result = structured_model.invoke(f'Classify this support ticket: {ticket}')
result

# %% [markdown]
# ## Think
# Why is a validated Pydantic object safer than asking the model to return JSON in plain text?
